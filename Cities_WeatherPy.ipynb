# %%
# Import the time library and the datetime module from the datetime library
import time
from datetime import datetime
from citipy import citipy
# Import the requests library.
import requests
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Import the API key.
from config import weather_api_key

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
#cities[1]
# Out:
# 601

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.  The following for loop isn't good enough since we are
#passing the information into a url.  Url's don't like spaces New York needs to be New+York.
#We can use enumerate to do this
#for i in range(len(cities)):
# Group cities in sets of 50 for logging purposes.
    #if (i % 50 == 0 and i >= 50):
     #   set_count += 1
     #   record_count = 1
     #   time.sleep(60)

    # Create endpoint URL with each city.
    #city_url = url + "&q=" + cities[i]
#for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    #if (i % 50 == 0 and i >= 50):
     #   set_count += 1
     #   record_count = 1
     #   time.sleep(60)

    # Create endpoint URL with each city.
    #city_url = url + "&q=" + cities[i]
    
# Loop through all the cities in the list using enumerate.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    #if .status_code == 200:
    #    print(f"City Weather found.")
    #else:
    #    print(f"City weather not found.")
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tuktoyaktuk
# Processing Record 2 of Set 1 | lebu
# Processing Record 3 of Set 1 | hobart
# Processing Record 4 of Set 1 | mataura
# Processing Record 5 of Set 1 | poum
# Processing Record 6 of Set 1 | kintampo
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | husavik
# Processing Record 9 of Set 1 | saskylakh
# Processing Record 10 of Set 1 | vaini
# Processing Record 11 of Set 1 | upernavik
# Processing Record 12 of Set 1 | yenagoa
# Processing Record 13 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 14 of Set 1 | yaan
# Processing Record 15 of Set 1 | walvis bay
# Processing Record 16 of Set 1 | lagoa
# Processing Record 17 of Set 1 | nikolskoye
# Processing Record 18 of Set 1 | lorengau
# Processing Record 19 of Set 1 | saint augustine
# Processing Record 20 of Set 1 | cherskiy
# Processing Record 21 of Set 1 | faanui
# Processing Record 22 of Set 1 | cockburn town
# Processing Record 23 of Set 1 | bambous virieux
# Processing Record 24 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 25 of Set 1 | gizo
# Processing Record 26 of Set 1 | bahir dar
# Processing Record 27 of Set 1 | yibin
# Processing Record 28 of Set 1 | london
# Processing Record 29 of Set 1 | cape town
# Processing Record 30 of Set 1 | rikitea
# Processing Record 31 of Set 1 | provideniya
# Processing Record 32 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 33 of Set 1 | castro
# Processing Record 34 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 35 of Set 1 | progreso
# Processing Record 36 of Set 1 | atuona
# Processing Record 37 of Set 1 | port elizabeth
# Processing Record 38 of Set 1 | bhimunipatnam
# Processing Record 39 of Set 1 | sao joao da barra
# Processing Record 40 of Set 1 | fuerte olimpo
# Processing Record 41 of Set 1 | vila velha
# Processing Record 42 of Set 1 | okandja
# City not found. Skipping...
# Processing Record 43 of Set 1 | knysna
# Processing Record 44 of Set 1 | silvassa
# Processing Record 45 of Set 1 | ostrovnoy
# Processing Record 46 of Set 1 | busselton
# Processing Record 47 of Set 1 | kapaa
# Processing Record 48 of Set 1 | montlucon
# Processing Record 49 of Set 1 | yulara
# Processing Record 50 of Set 1 | hambantota
# Processing Record 1 of Set 2 | udachnyy
# Processing Record 2 of Set 2 | ahipara
# Processing Record 3 of Set 2 | mar del plata
# Processing Record 4 of Set 2 | severo-kurilsk
# Processing Record 5 of Set 2 | kidal
# Processing Record 6 of Set 2 | bluff
# Processing Record 7 of Set 2 | ponta do sol
# Processing Record 8 of Set 2 | luderitz
# Processing Record 9 of Set 2 | talnakh
# Processing Record 10 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 2 | mount gambier
# Processing Record 12 of Set 2 | jamestown
# Processing Record 13 of Set 2 | boyolangu
# Processing Record 14 of Set 2 | broken hill
# Processing Record 15 of Set 2 | san carlos de bariloche
# Processing Record 16 of Set 2 | dikson
# Processing Record 17 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 18 of Set 2 | blagoyevo
# Processing Record 19 of Set 2 | divinopolis
# Processing Record 20 of Set 2 | langham
# Processing Record 21 of Set 2 | carnarvon
# Processing Record 22 of Set 2 | hilo
# Processing Record 23 of Set 2 | kruisfontein
# Processing Record 24 of Set 2 | constitucion
# Processing Record 25 of Set 2 | airai
# Processing Record 26 of Set 2 | cabo san lucas
# Processing Record 27 of Set 2 | ribeira grande
# Processing Record 28 of Set 2 | vila franca do campo
# Processing Record 29 of Set 2 | batagay
# Processing Record 30 of Set 2 | marica
# Processing Record 31 of Set 2 | artyk
# City not found. Skipping...
# Processing Record 32 of Set 2 | aklavik
# Processing Record 33 of Set 2 | pontalina
# Processing Record 34 of Set 2 | yellowknife
# Processing Record 35 of Set 2 | puro
# Processing Record 36 of Set 2 | paamiut
# Processing Record 37 of Set 2 | sitio novo do tocantins
# Processing Record 38 of Set 2 | san ramon de la nueva oran
# Processing Record 39 of Set 2 | karkaralinsk
# City not found. Skipping...
# Processing Record 40 of Set 2 | opuwo
# Processing Record 41 of Set 2 | gorontalo
# Processing Record 42 of Set 2 | rabo de peixe
# Processing Record 43 of Set 2 | warri
# Processing Record 44 of Set 2 | puerto ayora
# Processing Record 45 of Set 2 | salym
# Processing Record 46 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 47 of Set 2 | hermanus
# Processing Record 48 of Set 2 | yermish
# Processing Record 49 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 50 of Set 2 | qaanaaq
# Processing Record 1 of Set 3 | santa vitoria do palmar
# Processing Record 2 of Set 3 | sorvag
# City not found. Skipping...
# Processing Record 3 of Set 3 | thompson
# Processing Record 4 of Set 3 | valparaiso
# Processing Record 5 of Set 3 | bredasdorp
# Processing Record 6 of Set 3 | lubango
# Processing Record 7 of Set 3 | kaitangata
# Processing Record 8 of Set 3 | kodiak
# Processing Record 9 of Set 3 | albany
# Processing Record 10 of Set 3 | georgetown
# Processing Record 11 of Set 3 | pevek
# Processing Record 12 of Set 3 | coihaique
# Processing Record 13 of Set 3 | ushuaia
# Processing Record 14 of Set 3 | kavieng
# Processing Record 15 of Set 3 | stolin
# Processing Record 16 of Set 3 | ahuimanu
# Processing Record 17 of Set 3 | mercedes
# Processing Record 18 of Set 3 | skovorodino
# Processing Record 19 of Set 3 | nouadhibou
# Processing Record 20 of Set 3 | pervomayskoye
# Processing Record 21 of Set 3 | santa rosa
# Processing Record 22 of Set 3 | souillac
# Processing Record 23 of Set 3 | flagstaff
# Processing Record 24 of Set 3 | port alfred
# Processing Record 25 of Set 3 | urdzhar
# City not found. Skipping...
# Processing Record 26 of Set 3 | ruteng
# Processing Record 27 of Set 3 | gaoyou
# Processing Record 28 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 29 of Set 3 | churapcha
# Processing Record 30 of Set 3 | hamilton
# Processing Record 31 of Set 3 | nanortalik
# Processing Record 32 of Set 3 | grand gaube
# Processing Record 33 of Set 3 | batticaloa
# Processing Record 34 of Set 3 | fort nelson
# Processing Record 35 of Set 3 | novoselytsya
# Processing Record 36 of Set 3 | barrow
# Processing Record 37 of Set 3 | evensk
# Processing Record 38 of Set 3 | honningsvag
# Processing Record 39 of Set 3 | la colorada
# Processing Record 40 of Set 3 | east london
# Processing Record 41 of Set 3 | wrexham
# Processing Record 42 of Set 3 | khatanga
# Processing Record 43 of Set 3 | katsuura
# Processing Record 44 of Set 3 | esperance
# Processing Record 45 of Set 3 | lagos
# Processing Record 46 of Set 3 | haines junction
# Processing Record 47 of Set 3 | la ronge
# Processing Record 48 of Set 3 | mango
# Processing Record 49 of Set 3 | cairns
# Processing Record 50 of Set 3 | yomitan
# City not found. Skipping...
# Processing Record 1 of Set 4 | numazu
# Processing Record 2 of Set 4 | altagracia de orituco
# Processing Record 3 of Set 4 | tabuk
# Processing Record 4 of Set 4 | vestmannaeyjar
# Processing Record 5 of Set 4 | seoul
# Processing Record 6 of Set 4 | mahebourg
# Processing Record 7 of Set 4 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 8 of Set 4 | victoria
# Processing Record 9 of Set 4 | baghdad
# Processing Record 10 of Set 4 | tessalit
# Processing Record 11 of Set 4 | hofn
# Processing Record 12 of Set 4 | boksitogorsk
# Processing Record 13 of Set 4 | batagay-alyta
# Processing Record 14 of Set 4 | verkhnevilyuysk
# Processing Record 15 of Set 4 | launceston
# Processing Record 16 of Set 4 | dickinson
# Processing Record 17 of Set 4 | mingaora
# Processing Record 18 of Set 4 | fukue
# Processing Record 19 of Set 4 | haripur
# Processing Record 20 of Set 4 | miles city
# Processing Record 21 of Set 4 | payakumbuh
# Processing Record 22 of Set 4 | barbar
# City not found. Skipping...
# Processing Record 23 of Set 4 | rawson
# Processing Record 24 of Set 4 | saint-philippe
# Processing Record 25 of Set 4 | chuy
# Processing Record 26 of Set 4 | tonj
# Processing Record 27 of Set 4 | potosi
# Processing Record 28 of Set 4 | nagornskiy
# Processing Record 29 of Set 4 | manicore
# Processing Record 30 of Set 4 | oxford
# Processing Record 31 of Set 4 | sorong
# Processing Record 32 of Set 4 | kasongo
# Processing Record 33 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 34 of Set 4 | tefe
# Processing Record 35 of Set 4 | necochea
# Processing Record 36 of Set 4 | torbay
# Processing Record 37 of Set 4 | port lincoln
# Processing Record 38 of Set 4 | cidreira
# Processing Record 39 of Set 4 | afua
# Processing Record 40 of Set 4 | butaritari
# Processing Record 41 of Set 4 | longlac
# City not found. Skipping...
# Processing Record 42 of Set 4 | poya
# Processing Record 43 of Set 4 | honiara
# Processing Record 44 of Set 4 | hasaki
# Processing Record 45 of Set 4 | saint-augustin
# Processing Record 46 of Set 4 | belyy yar
# Processing Record 47 of Set 4 | kuito
# Processing Record 48 of Set 4 | arman
# Processing Record 49 of Set 4 | bethel
# Processing Record 50 of Set 4 | dingle
# Processing Record 1 of Set 5 | geraldton
# Processing Record 2 of Set 5 | manado
# Processing Record 3 of Set 5 | bereda
# Processing Record 4 of Set 5 | mehamn
# Processing Record 5 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 6 of Set 5 | biak
# Processing Record 7 of Set 5 | tiksi
# Processing Record 8 of Set 5 | allende
# Processing Record 9 of Set 5 | prince george
# Processing Record 10 of Set 5 | kalmunai
# Processing Record 11 of Set 5 | norman wells
# Processing Record 12 of Set 5 | avarua
# Processing Record 13 of Set 5 | pacific grove
# Processing Record 14 of Set 5 | tezu
# Processing Record 15 of Set 5 | longyearbyen
# Processing Record 16 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 17 of Set 5 | port townsend
# Processing Record 18 of Set 5 | puerto narino
# Processing Record 19 of Set 5 | saldanha
# Processing Record 20 of Set 5 | tecpan
# Processing Record 21 of Set 5 | sao felix do xingu
# Processing Record 22 of Set 5 | taoudenni
# Processing Record 23 of Set 5 | leningradskiy
# Processing Record 24 of Set 5 | chilliwack
# Processing Record 25 of Set 5 | silifke
# Processing Record 26 of Set 5 | port-gentil
# Processing Record 27 of Set 5 | clyde river
# Processing Record 28 of Set 5 | yulin
# Processing Record 29 of Set 5 | haselunne
# Processing Record 30 of Set 5 | meulaboh
# Processing Record 31 of Set 5 | sao filipe
# Processing Record 32 of Set 5 | narsaq
# Processing Record 33 of Set 5 | sabha
# Processing Record 34 of Set 5 | nianzishan
# Processing Record 35 of Set 5 | laguna
# Processing Record 36 of Set 5 | belmonte
# Processing Record 37 of Set 5 | craigieburn
# Processing Record 38 of Set 5 | laiwu
# Processing Record 39 of Set 5 | codrington
# Processing Record 40 of Set 5 | segovia
# Processing Record 41 of Set 5 | eugene
# Processing Record 42 of Set 5 | samana
# Processing Record 43 of Set 5 | asau
# Processing Record 44 of Set 5 | arraial do cabo
# Processing Record 45 of Set 5 | saltillo
# Processing Record 46 of Set 5 | bonavista
# Processing Record 47 of Set 5 | vardo
# Processing Record 48 of Set 5 | ambovombe
# Processing Record 49 of Set 5 | morondava
# Processing Record 50 of Set 5 | havoysund
# Processing Record 1 of Set 6 | saint george
# Processing Record 2 of Set 6 | tazmalt
# Processing Record 3 of Set 6 | bengkulu
# Processing Record 4 of Set 6 | amos
# Processing Record 5 of Set 6 | chabahar
# Processing Record 6 of Set 6 | dapaong
# Processing Record 7 of Set 6 | tabou
# Processing Record 8 of Set 6 | palauig
# Processing Record 9 of Set 6 | bilma
# Processing Record 10 of Set 6 | new norfolk
# Processing Record 11 of Set 6 | san patricio
# Processing Record 12 of Set 6 | luanda
# Processing Record 13 of Set 6 | chapais
# Processing Record 14 of Set 6 | broome
# Processing Record 15 of Set 6 | aksha
# Processing Record 16 of Set 6 | atar
# Processing Record 17 of Set 6 | kaoma
# Processing Record 18 of Set 6 | cambridge
# Processing Record 19 of Set 6 | novyy svit
# Processing Record 20 of Set 6 | iqaluit
# Processing Record 21 of Set 6 | bodden town
# Processing Record 22 of Set 6 | along
# Processing Record 23 of Set 6 | imbituba
# Processing Record 24 of Set 6 | kaseda
# Processing Record 25 of Set 6 | alyangula
# Processing Record 26 of Set 6 | margate
# Processing Record 27 of Set 6 | buraydah
# Processing Record 28 of Set 6 | ostersund
# Processing Record 29 of Set 6 | lahat
# Processing Record 30 of Set 6 | lahaina
# Processing Record 31 of Set 6 | vilhena
# Processing Record 32 of Set 6 | rindal
# Processing Record 33 of Set 6 | dudinka
# Processing Record 34 of Set 6 | sistranda
# Processing Record 35 of Set 6 | tasiilaq
# Processing Record 36 of Set 6 | college
# Processing Record 37 of Set 6 | abu kamal
# Processing Record 38 of Set 6 | nokaneng
# Processing Record 39 of Set 6 | wewak
# Processing Record 40 of Set 6 | roma
# Processing Record 41 of Set 6 | semey
# Processing Record 42 of Set 6 | asosa
# Processing Record 43 of Set 6 | arlit
# Processing Record 44 of Set 6 | marawi
# Processing Record 45 of Set 6 | whitehorse
# Processing Record 46 of Set 6 | las vegas
# Processing Record 47 of Set 6 | yumen
# Processing Record 48 of Set 6 | nuuk
# Processing Record 49 of Set 6 | macusani
# Processing Record 50 of Set 6 | cap malheureux
# Processing Record 1 of Set 7 | havre-saint-pierre
# Processing Record 2 of Set 7 | jiayuguan
# Processing Record 3 of Set 7 | ornskoldsvik
# Processing Record 4 of Set 7 | eureka
# Processing Record 5 of Set 7 | gat
# Processing Record 6 of Set 7 | nioro
# Processing Record 7 of Set 7 | huescar
# Processing Record 8 of Set 7 | lebedinyy
# Processing Record 9 of Set 7 | campbellsville
# Processing Record 10 of Set 7 | tingo maria
# Processing Record 11 of Set 7 | deputatskiy
# Processing Record 12 of Set 7 | puerto escondido
# Processing Record 13 of Set 7 | safwah
# City not found. Skipping...
# Processing Record 14 of Set 7 | paradwip
# City not found. Skipping...
# Processing Record 15 of Set 7 | nishihara
# Processing Record 16 of Set 7 | indaparapeo
# Processing Record 17 of Set 7 | caravelas
# Processing Record 18 of Set 7 | kameshkovo
# Processing Record 19 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 20 of Set 7 | palasa
# Processing Record 21 of Set 7 | igrim
# Processing Record 22 of Set 7 | sur
# Processing Record 23 of Set 7 | alofi
# Processing Record 24 of Set 7 | kirakira
# Processing Record 25 of Set 7 | berlevag
# Processing Record 26 of Set 7 | bulgan
# Processing Record 27 of Set 7 | den helder
# Processing Record 28 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 29 of Set 7 | takoradi
# Processing Record 30 of Set 7 | omboue
# Processing Record 31 of Set 7 | wagar
# Processing Record 32 of Set 7 | turukhansk
# Processing Record 33 of Set 7 | hithadhoo
# Processing Record 34 of Set 7 | el penon
# Processing Record 35 of Set 7 | olafsvik
# Processing Record 36 of Set 7 | oakdale
# Processing Record 37 of Set 7 | ancud
# Processing Record 38 of Set 7 | mende
# Processing Record 39 of Set 7 | mwinilunga
# Processing Record 40 of Set 7 | jalu
# Processing Record 41 of Set 7 | maldonado
# Processing Record 42 of Set 7 | richards bay
# Processing Record 43 of Set 7 | phan rang
# City not found. Skipping...
# Processing Record 44 of Set 7 | fairbanks
# Processing Record 45 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 46 of Set 7 | lompoc
# Processing Record 47 of Set 7 | zabaykalsk
# Processing Record 48 of Set 7 | vila
# Processing Record 49 of Set 7 | council bluffs
# Processing Record 50 of Set 7 | port macquarie
# Processing Record 1 of Set 8 | talah
# City not found. Skipping...
# Processing Record 2 of Set 8 | ilulissat
# Processing Record 3 of Set 8 | aguimes
# Processing Record 4 of Set 8 | hun
# Processing Record 5 of Set 8 | quebradanegra
# Processing Record 6 of Set 8 | batsfjord
# Processing Record 7 of Set 8 | exu
# Processing Record 8 of Set 8 | okha
# Processing Record 9 of Set 8 | metro
# Processing Record 10 of Set 8 | wageningen
# Processing Record 11 of Set 8 | alice springs
# Processing Record 12 of Set 8 | inhambane
# Processing Record 13 of Set 8 | lincoln
# Processing Record 14 of Set 8 | derzhavinsk
# Processing Record 15 of Set 8 | cascais
# Processing Record 16 of Set 8 | filimonovo
# Processing Record 17 of Set 8 | yining
# Processing Record 18 of Set 8 | tuatapere
# Processing Record 19 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 20 of Set 8 | song phi nong
# Processing Record 21 of Set 8 | carauari
# Processing Record 22 of Set 8 | merauke
# Processing Record 23 of Set 8 | zabol
# Processing Record 24 of Set 8 | kaa-khem
# Processing Record 25 of Set 8 | santiago
# Processing Record 26 of Set 8 | wanxian
# Processing Record 27 of Set 8 | noumea
# Processing Record 28 of Set 8 | guilin
# Processing Record 29 of Set 8 | pontes e lacerda
# Processing Record 30 of Set 8 | nandi
# Processing Record 31 of Set 8 | avera
# Processing Record 32 of Set 8 | manga
# Processing Record 33 of Set 8 | itarema
# Processing Record 34 of Set 8 | izhma
# Processing Record 35 of Set 8 | andevoranto
# City not found. Skipping...
# Processing Record 36 of Set 8 | hoquiam
# Processing Record 37 of Set 8 | kolpashevo
# Processing Record 38 of Set 8 | zyryanka
# Processing Record 39 of Set 8 | nipawin
# Processing Record 40 of Set 8 | wonthaggi
# Processing Record 41 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 42 of Set 8 | waddan
# Processing Record 43 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 44 of Set 8 | cape coast
# Processing Record 45 of Set 8 | novobirilyussy
# Processing Record 46 of Set 8 | middelburg
# Processing Record 47 of Set 8 | areka
# Processing Record 48 of Set 8 | alcacer do sal
# Processing Record 49 of Set 8 | kargasok
# Processing Record 50 of Set 8 | simpang
# Processing Record 1 of Set 9 | shenjiamen
# Processing Record 2 of Set 9 | coquimbo
# Processing Record 3 of Set 9 | sitka
# Processing Record 4 of Set 9 | touros
# Processing Record 5 of Set 9 | sao bento do una
# City not found. Skipping...
# Processing Record 6 of Set 9 | zapolyarnyy
# Processing Record 7 of Set 9 | ratnagiri
# Processing Record 8 of Set 9 | xining
# Processing Record 9 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 10 of Set 9 | kinshasa
# Processing Record 11 of Set 9 | auki
# Processing Record 12 of Set 9 | rocha
# Processing Record 13 of Set 9 | erenhot
# Processing Record 14 of Set 9 | qaqortoq
# Processing Record 15 of Set 9 | rincon
# Processing Record 16 of Set 9 | labytnangi
# Processing Record 17 of Set 9 | bolobo
# Processing Record 18 of Set 9 | wainwright
# Processing Record 19 of Set 9 | preobrazheniye
# Processing Record 20 of Set 9 | veliki preslav
# Processing Record 21 of Set 9 | namibe
# Processing Record 22 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 23 of Set 9 | kilcullen
# Processing Record 24 of Set 9 | nakamura
# Processing Record 25 of Set 9 | malakal
# Processing Record 26 of Set 9 | yarada
# Processing Record 27 of Set 9 | manono
# Processing Record 28 of Set 9 | pangnirtung
# Processing Record 29 of Set 9 | ghelinta
# Processing Record 30 of Set 9 | labuan
# Processing Record 31 of Set 9 | tokur
# Processing Record 32 of Set 9 | mesquite
# Processing Record 33 of Set 9 | mahajanga
# Processing Record 34 of Set 9 | ravar
# Processing Record 35 of Set 9 | korla
# Processing Record 36 of Set 9 | rio gallegos
# Processing Record 37 of Set 9 | muli
# Processing Record 38 of Set 9 | talcahuano
# Processing Record 39 of Set 9 | manacapuru
# Processing Record 40 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 41 of Set 9 | lavrentiya
# Processing Record 42 of Set 9 | hailar
# Processing Record 43 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 44 of Set 9 | minatitlan
# Processing Record 45 of Set 9 | bardiyah
# Processing Record 46 of Set 9 | dunedin
# Processing Record 47 of Set 9 | cayenne
# Processing Record 48 of Set 9 | aykhal
# Processing Record 49 of Set 9 | henties bay
# Processing Record 50 of Set 9 | klaksvik
# Processing Record 1 of Set 10 | saint-pierre
# Processing Record 2 of Set 10 | svetlogorsk
# Processing Record 3 of Set 10 | toora-khem
# Processing Record 4 of Set 10 | zhigansk
# Processing Record 5 of Set 10 | kamachumu
# Processing Record 6 of Set 10 | prabumulih
# Processing Record 7 of Set 10 | oktyabrskiy
# Processing Record 8 of Set 10 | segezha
# Processing Record 9 of Set 10 | naze
# Processing Record 10 of Set 10 | lodwar
# Processing Record 11 of Set 10 | shizunai
# Processing Record 12 of Set 10 | uwayl
# City not found. Skipping...
# Processing Record 13 of Set 10 | fontenay-le-comte
# Processing Record 14 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 15 of Set 10 | hay river
# Processing Record 16 of Set 10 | kulhudhuffushi
# Processing Record 17 of Set 10 | batemans bay
# Processing Record 18 of Set 10 | sinnamary
# Processing Record 19 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 20 of Set 10 | new ulm
# Processing Record 21 of Set 10 | grimari
# City not found. Skipping...
# Processing Record 22 of Set 10 | woodward
# Processing Record 23 of Set 10 | saryg-sep
# Processing Record 24 of Set 10 | elko
# Processing Record 25 of Set 10 | istok
# Processing Record 26 of Set 10 | betioky
# Processing Record 27 of Set 10 | wladyslawowo
# Processing Record 28 of Set 10 | mujiayingzi
# Processing Record 29 of Set 10 | salalah
# Processing Record 30 of Set 10 | srednekolymsk
# Processing Record 31 of Set 10 | butia
# Processing Record 32 of Set 10 | basco
# Processing Record 33 of Set 10 | farmington
# Processing Record 34 of Set 10 | inuvik
# Processing Record 35 of Set 10 | poindimie
# Processing Record 36 of Set 10 | nome
# Processing Record 37 of Set 10 | chakwal
# Processing Record 38 of Set 10 | acapulco
# Processing Record 39 of Set 10 | jerome
# Processing Record 40 of Set 10 | san policarpo
# Processing Record 41 of Set 10 | ulladulla
# Processing Record 42 of Set 10 | atasu
# Processing Record 43 of Set 10 | thomasville
# Processing Record 44 of Set 10 | tortoli
# Processing Record 45 of Set 10 | homer
# Processing Record 46 of Set 10 | high level
# Processing Record 47 of Set 10 | moerai
# Processing Record 48 of Set 10 | alexandria
# Processing Record 49 of Set 10 | diffa
# Processing Record 50 of Set 10 | kemi
# Processing Record 1 of Set 11 | ust-uda
# Processing Record 2 of Set 11 | baykit
# Processing Record 3 of Set 11 | lasa
# Processing Record 4 of Set 11 | hoi an
# Processing Record 5 of Set 11 | fort smith
# Processing Record 6 of Set 11 | aswan
# Processing Record 7 of Set 11 | farafangana
# Processing Record 8 of Set 11 | ahvaz
# Processing Record 9 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 10 of Set 11 | qostanay
# Processing Record 11 of Set 11 | hollister
# Processing Record 12 of Set 11 | beringovskiy
# Processing Record 13 of Set 11 | bilibino
# Processing Record 14 of Set 11 | villablino
# Processing Record 15 of Set 11 | san quintin
# Processing Record 16 of Set 11 | vao
# Processing Record 17 of Set 11 | keetmanshoop
# Processing Record 18 of Set 11 | te anau
# Processing Record 19 of Set 11 | amahai
# Processing Record 20 of Set 11 | manzanillo
# Processing Record 21 of Set 11 | port blair
# Processing Record 22 of Set 11 | los llanos de aridane
# Processing Record 23 of Set 11 | sneek
# Processing Record 24 of Set 11 | komsomolskiy
# Processing Record 25 of Set 11 | vanimo
# Processing Record 26 of Set 11 | umm durman
# City not found. Skipping...
# Processing Record 27 of Set 11 | taltal
# Processing Record 28 of Set 11 | formoso do araguaia
# City not found. Skipping...
# Processing Record 29 of Set 11 | gigmoto
# Processing Record 30 of Set 11 | parana
# Processing Record 31 of Set 11 | flin flon
# Processing Record 32 of Set 11 | mezen
# Processing Record 33 of Set 11 | tshikapa
# Processing Record 34 of Set 11 | kijang
# Processing Record 35 of Set 11 | hervey bay
# Processing Record 36 of Set 11 | pisco
# Processing Record 37 of Set 11 | tuggurt
# City not found. Skipping...
# Processing Record 38 of Set 11 | regidor
# Processing Record 39 of Set 11 | avenal
# Processing Record 40 of Set 11 | sovetskaya gavan
# Processing Record 41 of Set 11 | mansa
# Processing Record 42 of Set 11 | north myrtle beach
# Processing Record 43 of Set 11 | ketchikan
# Processing Record 44 of Set 11 | luwuk
# Processing Record 45 of Set 11 | bay village
# Processing Record 46 of Set 11 | belaya gora
# Processing Record 47 of Set 11 | aksarka
# Processing Record 48 of Set 11 | maniitsoq
# Processing Record 49 of Set 11 | ierapetra
# Processing Record 50 of Set 11 | san jose
# Processing Record 1 of Set 12 | dno
# Processing Record 2 of Set 12 | yerbogachen
# Processing Record 3 of Set 12 | wulanhaote
# City not found. Skipping...
# Processing Record 4 of Set 12 | lata
# Processing Record 5 of Set 12 | kahului
# Processing Record 6 of Set 12 | baruun-urt
# Processing Record 7 of Set 12 | zlobin
# Processing Record 8 of Set 12 | cascas
# Processing Record 9 of Set 12 | khomeyn
# Processing Record 10 of Set 12 | padang
# Processing Record 11 of Set 12 | alice
# Processing Record 12 of Set 12 | baft
# Processing Record 13 of Set 12 | bubaque
# Processing Record 14 of Set 12 | chicama
# Processing Record 15 of Set 12 | san rafael
# Processing Record 16 of Set 12 | manaure
# Processing Record 17 of Set 12 | popondetta
# Processing Record 18 of Set 12 | tutoia
# Processing Record 19 of Set 12 | gladstone
# Processing Record 20 of Set 12 | north bend
# Processing Record 21 of Set 12 | maceio
# Processing Record 22 of Set 12 | kikwit
# Processing Record 23 of Set 12 | perehonivka
# Processing Record 24 of Set 12 | faya
# Processing Record 25 of Set 12 | labuhan
# Processing Record 26 of Set 12 | anchorage
# Processing Record 27 of Set 12 | guanica
# Processing Record 28 of Set 12 | kochevo
# Processing Record 29 of Set 12 | hobyo
# Processing Record 30 of Set 12 | bundaberg
# Processing Record 31 of Set 12 | erdenet
# Processing Record 32 of Set 12 | burnie
# Processing Record 33 of Set 12 | abnub
# Processing Record 34 of Set 12 | lakatoro
# Processing Record 35 of Set 12 | menongue
# Processing Record 36 of Set 12 | kadykchan
# City not found. Skipping...
# Processing Record 37 of Set 12 | flinders
# Processing Record 38 of Set 12 | glencoe
# Processing Record 39 of Set 12 | aasiaat
# Processing Record 40 of Set 12 | magadan
# Processing Record 41 of Set 12 | zhengjiatun
# Processing Record 42 of Set 12 | zatoka
# Processing Record 43 of Set 12 | rizhao
# Processing Record 44 of Set 12 | pribelskiy
# City not found. Skipping...
# Processing Record 45 of Set 12 | dali
# Processing Record 46 of Set 12 | goiatuba
# Processing Record 47 of Set 12 | ngukurr
# City not found. Skipping...
# Processing Record 48 of Set 12 | katherine
# Processing Record 49 of Set 12 | elizabeth city
# Processing Record 50 of Set 12 | maunabo
# Processing Record 1 of Set 13 | yiyang
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 552

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  Tuktoyaktuk  69.4541 -133.0374      8.60        92         100        4.61
# 1         Lebu -37.6167  -73.6500     58.98        89           4       15.05
# 2       Hobart -42.8794  147.3294     62.26        67          98        3.00
# 3      Mataura -46.1927  168.8643     45.07        97         100        8.52
# 4         Poum -20.2333  164.0167     79.45        76          27        4.61
#
#   Country                 Date
# 0      CA  2022-11-23 22:42:43
# 1      CL  2022-11-23 22:42:44
# 2      AU  2022-11-23 22:42:22
# 3      NZ  2022-11-23 22:42:44
# 4      NC  2022-11-23 22:42:44

# %%
#Lets re-order the columns 
new_column_order = ['City', 'Country', 'Date', 'Lat', 'Lng', 'Max Temp', 'Humidity','Cloudiness', 'Wind Speed']
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#           City Country                 Date      Lat       Lng  Max Temp  \
# 0  Tuktoyaktuk      CA  2022-11-23 22:42:43  69.4541 -133.0374      8.60
# 1         Lebu      CL  2022-11-23 22:42:44 -37.6167  -73.6500     58.98
# 2       Hobart      AU  2022-11-23 22:42:22 -42.8794  147.3294     62.26
# 3      Mataura      NZ  2022-11-23 22:42:44 -46.1927  168.8643     45.07
# 4         Poum      NC  2022-11-23 22:42:44 -20.2333  164.0167     79.45
#
#    Humidity  Cloudiness  Wind Speed
# 0        92         100        4.61
# 1        89           4       15.05
# 2        67          98        3.00
# 3        97         100        8.52
# 4        76          27        4.61

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
