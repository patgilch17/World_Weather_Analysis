# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90,90, size=2000)
lngs = np.random.uniform(-180,180,size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats,lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)
print(lat_lngs)
# Out:
# <zip object at 0x7f8ac14c2f00>

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(len(cities))
# Out:
# 744

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key
from pprint import pprint

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
#url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key+"&q="+"Paris"
#city_weather = requests.get(url).json()
#city_data=[]

#lat = city_weather['coord']['lat']
#lng = city_weather['coord']['lon']
#temp = city_weather['main']['temp_max']
#humidity = city_weather['main']['humidity']
#clouds = city_weather['clouds']['all']
#wind = city_weather['wind']['speed']
#country = city_weather['sys']['country']
#wdescrip = city_weather['weather'][0]['description']
        
        # Append the city information into the city_data list
#city_data['City'] = 'Paris'
#city_data['Country']= country
#city_data['Latitude']= lat
#city_data['Longitude']= lng
#city_data['Temp High']= temp
#city_data['Humidity']= humidity
#city_data['Cloudiness']= clouds
#city_data['Wind Speed']= wind
#city_data['Weather Description']= wdescrip

#city_data.append({"City": 'Paris',
                    #"Lat": lat,
                    #"Lng": lng,
                    #"Max Temp": temp,
                    #"Humidity": humidity,
                    #"Cloudiness": clouds,
                    #"Wind Speed": wind,
                    #"Country": country})


#city_data


#pprint(url_data)

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    #type(city)
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        # YOUR CODE HERE       
        lat = city_weather['coord']['lat']
        lng = city_weather['coord']['lon']
        temp = city_weather['main']['temp_max']
        humidity = city_weather['main']['humidity']
        clouds = city_weather['clouds']['all']
        wind = city_weather['wind']['speed']
        country = city_weather['sys']['country']
        wdescrip = city_weather['weather'][0]['description']
        
        # Append the city information into the city_data list
        #city_data['City'] = city
        #city_data['Country']= country
        #city_data['Latitude']= lat
        #city_data['Longitude']= lng
        #city_data['Temp High']= temp
        #city_data['Humidity']= humidity
        #city_data['Cloudiness']= clouds
        #city_data['Wind Speed']= wind
        #city_data['Weather Description']= wdescrip
        
        city_data.append({"City": city.title(),"Country": country,"Lat": lat,"Lng": lng,"Max Temp": temp,"Humidity": humidity,"Cloudiness": clouds,"Wind Speed": wind,'Weather Description': wdescrip})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | yellowknife
# Processing Record 2 of Set 1 | hobart
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | port alfred
# Processing Record 5 of Set 1 | hermanus
# Processing Record 6 of Set 1 | castro
# Processing Record 7 of Set 1 | hasaki
# Processing Record 8 of Set 1 | vila velha
# Processing Record 9 of Set 1 | grindavik
# Processing Record 10 of Set 1 | zhigalovo
# Processing Record 11 of Set 1 | jamestown
# Processing Record 12 of Set 1 | yumen
# Processing Record 13 of Set 1 | iqaluit
# Processing Record 14 of Set 1 | atuona
# Processing Record 15 of Set 1 | aswan
# Processing Record 16 of Set 1 | bambous virieux
# Processing Record 17 of Set 1 | avarua
# Processing Record 18 of Set 1 | tres arroyos
# Processing Record 19 of Set 1 | port blair
# Processing Record 20 of Set 1 | puerto ayora
# Processing Record 21 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 22 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 23 of Set 1 | punta arenas
# Processing Record 24 of Set 1 | esperanza
# Processing Record 25 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 26 of Set 1 | kombissiri
# Processing Record 27 of Set 1 | rikitea
# Processing Record 28 of Set 1 | sept-iles
# Processing Record 29 of Set 1 | nemuro
# Processing Record 30 of Set 1 | busselton
# Processing Record 31 of Set 1 | victoria
# Processing Record 32 of Set 1 | ahero
# Processing Record 33 of Set 1 | vyazemskiy
# Processing Record 34 of Set 1 | ushuaia
# Processing Record 35 of Set 1 | kapaa
# Processing Record 36 of Set 1 | pevek
# Processing Record 37 of Set 1 | buraydah
# Processing Record 38 of Set 1 | saskylakh
# Processing Record 39 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 1 | souillac
# Processing Record 41 of Set 1 | east london
# Processing Record 42 of Set 1 | dikson
# Processing Record 43 of Set 1 | karaul
# City not found. Skipping...
# Processing Record 44 of Set 1 | hambantota
# Processing Record 45 of Set 1 | bur gabo
# City not found. Skipping...
# Processing Record 46 of Set 1 | kodiak
# Processing Record 47 of Set 1 | sao felix do xingu
# Processing Record 48 of Set 1 | boende
# Processing Record 49 of Set 1 | qaanaaq
# Processing Record 50 of Set 1 | albany
# Processing Record 1 of Set 2 | krasnoselkup
# Processing Record 2 of Set 2 | crab hill
# City not found. Skipping...
# Processing Record 3 of Set 2 | tiksi
# Processing Record 4 of Set 2 | ngong
# Processing Record 5 of Set 2 | hithadhoo
# Processing Record 6 of Set 2 | kundiawa
# Processing Record 7 of Set 2 | santa maria
# Processing Record 8 of Set 2 | caravelas
# Processing Record 9 of Set 2 | praia da vitoria
# Processing Record 10 of Set 2 | faanui
# Processing Record 11 of Set 2 | puerto colombia
# Processing Record 12 of Set 2 | bluff
# Processing Record 13 of Set 2 | cazones
# Processing Record 14 of Set 2 | nevsehir
# Processing Record 15 of Set 2 | pangnirtung
# Processing Record 16 of Set 2 | hilo
# Processing Record 17 of Set 2 | vaini
# Processing Record 18 of Set 2 | nieuw amsterdam
# Processing Record 19 of Set 2 | asau
# Processing Record 20 of Set 2 | la ronge
# Processing Record 21 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 22 of Set 2 | vereshchagino
# Processing Record 23 of Set 2 | conceicao do araguaia
# Processing Record 24 of Set 2 | georgetown
# Processing Record 25 of Set 2 | bara
# Processing Record 26 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 27 of Set 2 | chuy
# Processing Record 28 of Set 2 | cape town
# Processing Record 29 of Set 2 | luderitz
# Processing Record 30 of Set 2 | rio gallegos
# Processing Record 31 of Set 2 | malwan
# City not found. Skipping...
# Processing Record 32 of Set 2 | sao filipe
# Processing Record 33 of Set 2 | saint george
# Processing Record 34 of Set 2 | homer
# Processing Record 35 of Set 2 | barrow
# Processing Record 36 of Set 2 | bredasdorp
# Processing Record 37 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 38 of Set 2 | butaritari
# Processing Record 39 of Set 2 | kavieng
# Processing Record 40 of Set 2 | kem
# Processing Record 41 of Set 2 | bolton
# Processing Record 42 of Set 2 | khatanga
# Processing Record 43 of Set 2 | mareeba
# Processing Record 44 of Set 2 | aklavik
# Processing Record 45 of Set 2 | ust-nera
# Processing Record 46 of Set 2 | lerwick
# Processing Record 47 of Set 2 | ratnagiri
# Processing Record 48 of Set 2 | mahadday weyne
# City not found. Skipping...
# Processing Record 49 of Set 2 | nanortalik
# Processing Record 50 of Set 2 | elizabeth city
# Processing Record 1 of Set 3 | anadyr
# Processing Record 2 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 3 of Set 3 | vila franca do campo
# Processing Record 4 of Set 3 | bengkulu
# Processing Record 5 of Set 3 | portland
# Processing Record 6 of Set 3 | sambava
# Processing Record 7 of Set 3 | sitka
# Processing Record 8 of Set 3 | jieshi
# Processing Record 9 of Set 3 | cherskiy
# Processing Record 10 of Set 3 | ozu
# Processing Record 11 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 12 of Set 3 | ravar
# Processing Record 13 of Set 3 | comodoro rivadavia
# Processing Record 14 of Set 3 | lavrentiya
# Processing Record 15 of Set 3 | roches noires
# City not found. Skipping...
# Processing Record 16 of Set 3 | broome
# Processing Record 17 of Set 3 | lake havasu city
# Processing Record 18 of Set 3 | camacha
# Processing Record 19 of Set 3 | kamenka
# Processing Record 20 of Set 3 | dingle
# Processing Record 21 of Set 3 | kaitangata
# Processing Record 22 of Set 3 | flin flon
# Processing Record 23 of Set 3 | gurgan
# City not found. Skipping...
# Processing Record 24 of Set 3 | mahebourg
# Processing Record 25 of Set 3 | ban nahin
# Processing Record 26 of Set 3 | kenai
# Processing Record 27 of Set 3 | port lincoln
# Processing Record 28 of Set 3 | praya
# Processing Record 29 of Set 3 | mogadishu
# Processing Record 30 of Set 3 | goderich
# Processing Record 31 of Set 3 | cidreira
# Processing Record 32 of Set 3 | harper
# Processing Record 33 of Set 3 | san blas
# Processing Record 34 of Set 3 | pemangkat
# Processing Record 35 of Set 3 | cabo san lucas
# Processing Record 36 of Set 3 | bud
# Processing Record 37 of Set 3 | rawson
# Processing Record 38 of Set 3 | port elizabeth
# Processing Record 39 of Set 3 | nome
# Processing Record 40 of Set 3 | teknaf
# Processing Record 41 of Set 3 | araouane
# Processing Record 42 of Set 3 | mehamn
# Processing Record 43 of Set 3 | aquin
# Processing Record 44 of Set 3 | isangel
# Processing Record 45 of Set 3 | sagae
# Processing Record 46 of Set 3 | fortuna
# Processing Record 47 of Set 3 | severo-kurilsk
# Processing Record 48 of Set 3 | amahai
# Processing Record 49 of Set 3 | new norfolk
# Processing Record 50 of Set 3 | veraval
# Processing Record 1 of Set 4 | geraldton
# Processing Record 2 of Set 4 | hovd
# Processing Record 3 of Set 4 | korla
# Processing Record 4 of Set 4 | nikolskoye
# Processing Record 5 of Set 4 | babanusah
# City not found. Skipping...
# Processing Record 6 of Set 4 | mar del plata
# Processing Record 7 of Set 4 | muroto
# Processing Record 8 of Set 4 | santiago del estero
# Processing Record 9 of Set 4 | qandahar
# City not found. Skipping...
# Processing Record 10 of Set 4 | umm lajj
# Processing Record 11 of Set 4 | airai
# Processing Record 12 of Set 4 | berlevag
# Processing Record 13 of Set 4 | thompson
# Processing Record 14 of Set 4 | tuktoyaktuk
# Processing Record 15 of Set 4 | jiddah
# City not found. Skipping...
# Processing Record 16 of Set 4 | upernavik
# Processing Record 17 of Set 4 | ixtapa
# Processing Record 18 of Set 4 | yangambi
# Processing Record 19 of Set 4 | chapais
# Processing Record 20 of Set 4 | acapulco
# Processing Record 21 of Set 4 | letnica
# Processing Record 22 of Set 4 | nantucket
# Processing Record 23 of Set 4 | takaka
# Processing Record 24 of Set 4 | daan
# Processing Record 25 of Set 4 | paungde
# Processing Record 26 of Set 4 | riyadh
# Processing Record 27 of Set 4 | burriana
# Processing Record 28 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 29 of Set 4 | saldanha
# Processing Record 30 of Set 4 | utiroa
# City not found. Skipping...
# Processing Record 31 of Set 4 | richard toll
# City not found. Skipping...
# Processing Record 32 of Set 4 | ribeira grande
# Processing Record 33 of Set 4 | narsaq
# Processing Record 34 of Set 4 | kholodnyy
# Processing Record 35 of Set 4 | sobolevo
# Processing Record 36 of Set 4 | fare
# Processing Record 37 of Set 4 | lexington
# Processing Record 38 of Set 4 | belyy yar
# Processing Record 39 of Set 4 | port moresby
# Processing Record 40 of Set 4 | cayenne
# Processing Record 41 of Set 4 | bolshoye selo
# Processing Record 42 of Set 4 | torbay
# Processing Record 43 of Set 4 | tuljapur
# Processing Record 44 of Set 4 | monrovia
# Processing Record 45 of Set 4 | shakawe
# Processing Record 46 of Set 4 | bethel
# Processing Record 47 of Set 4 | yabassi
# Processing Record 48 of Set 4 | jiuquan
# Processing Record 49 of Set 4 | manicore
# Processing Record 50 of Set 4 | iquique
# Processing Record 1 of Set 5 | fort-shevchenko
# Processing Record 2 of Set 5 | belaya gora
# Processing Record 3 of Set 5 | khandyga
# Processing Record 4 of Set 5 | emerald
# Processing Record 5 of Set 5 | port hardy
# Processing Record 6 of Set 5 | taltal
# Processing Record 7 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 8 of Set 5 | semey
# Processing Record 9 of Set 5 | miramar
# Processing Record 10 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 11 of Set 5 | saint-joseph
# Processing Record 12 of Set 5 | jubb jannin
# City not found. Skipping...
# Processing Record 13 of Set 5 | san patricio
# Processing Record 14 of Set 5 | oriximina
# Processing Record 15 of Set 5 | tranas
# Processing Record 16 of Set 5 | igarka
# Processing Record 17 of Set 5 | tabou
# Processing Record 18 of Set 5 | gorom-gorom
# Processing Record 19 of Set 5 | coquimbo
# Processing Record 20 of Set 5 | beringovskiy
# Processing Record 21 of Set 5 | mayo
# Processing Record 22 of Set 5 | saint-pierre
# Processing Record 23 of Set 5 | kibara
# Processing Record 24 of Set 5 | lorengau
# Processing Record 25 of Set 5 | pochutla
# Processing Record 26 of Set 5 | alofi
# Processing Record 27 of Set 5 | phan thiet
# Processing Record 28 of Set 5 | richards bay
# Processing Record 29 of Set 5 | lebu
# Processing Record 30 of Set 5 | yerbogachen
# Processing Record 31 of Set 5 | ayan
# Processing Record 32 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 33 of Set 5 | orlik
# Processing Record 34 of Set 5 | novoagansk
# Processing Record 35 of Set 5 | tomatlan
# Processing Record 36 of Set 5 | tasiilaq
# Processing Record 37 of Set 5 | quesnel
# Processing Record 38 of Set 5 | guerrero negro
# Processing Record 39 of Set 5 | lompoc
# Processing Record 40 of Set 5 | te anau
# Processing Record 41 of Set 5 | machico
# Processing Record 42 of Set 5 | yar-sale
# Processing Record 43 of Set 5 | lardos
# Processing Record 44 of Set 5 | rosario do sul
# Processing Record 45 of Set 5 | meulaboh
# Processing Record 46 of Set 5 | havre-saint-pierre
# Processing Record 47 of Set 5 | anloga
# Processing Record 48 of Set 5 | puerto leguizamo
# Processing Record 49 of Set 5 | golden rock
# City not found. Skipping...
# Processing Record 50 of Set 5 | laguna
# Processing Record 1 of Set 6 | somerset
# Processing Record 2 of Set 6 | linkoping
# Processing Record 3 of Set 6 | medford
# Processing Record 4 of Set 6 | constitucion
# Processing Record 5 of Set 6 | provideniya
# Processing Record 6 of Set 6 | sawtell
# Processing Record 7 of Set 6 | constantine
# Processing Record 8 of Set 6 | gigmoto
# Processing Record 9 of Set 6 | baker
# Processing Record 10 of Set 6 | iwanai
# Processing Record 11 of Set 6 | kikwit
# Processing Record 12 of Set 6 | yining
# Processing Record 13 of Set 6 | muzquiz
# City not found. Skipping...
# Processing Record 14 of Set 6 | ponta do sol
# Processing Record 15 of Set 6 | paamiut
# Processing Record 16 of Set 6 | klaksvik
# Processing Record 17 of Set 6 | yirol
# City not found. Skipping...
# Processing Record 18 of Set 6 | palmer
# Processing Record 19 of Set 6 | inta
# Processing Record 20 of Set 6 | coihaique
# Processing Record 21 of Set 6 | dhidhdhoo
# Processing Record 22 of Set 6 | mount darwin
# Processing Record 23 of Set 6 | zheleznodorozhnyy
# Processing Record 24 of Set 6 | omsukchan
# Processing Record 25 of Set 6 | salalah
# Processing Record 26 of Set 6 | sola
# Processing Record 27 of Set 6 | atlantic city
# Processing Record 28 of Set 6 | tautira
# Processing Record 29 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 30 of Set 6 | aguilas
# Processing Record 31 of Set 6 | mount gambier
# Processing Record 32 of Set 6 | polunochnoye
# Processing Record 33 of Set 6 | baghdad
# Processing Record 34 of Set 6 | xuddur
# Processing Record 35 of Set 6 | prince rupert
# Processing Record 36 of Set 6 | yulara
# Processing Record 37 of Set 6 | staryy nadym
# Processing Record 38 of Set 6 | rudbar
# Processing Record 39 of Set 6 | westport
# Processing Record 40 of Set 6 | lovington
# Processing Record 41 of Set 6 | chokurdakh
# Processing Record 42 of Set 6 | ancud
# Processing Record 43 of Set 6 | labutta
# City not found. Skipping...
# Processing Record 44 of Set 6 | henties bay
# Processing Record 45 of Set 6 | valera
# Processing Record 46 of Set 6 | oyama
# Processing Record 47 of Set 6 | natal
# Processing Record 48 of Set 6 | aurillac
# Processing Record 49 of Set 6 | dunedin
# Processing Record 50 of Set 6 | eydhafushi
# Processing Record 1 of Set 7 | china
# Processing Record 2 of Set 7 | dalian
# Processing Record 3 of Set 7 | lashio
# Processing Record 4 of Set 7 | hervey bay
# Processing Record 5 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 6 of Set 7 | jalu
# Processing Record 7 of Set 7 | hamilton
# Processing Record 8 of Set 7 | kochi
# Processing Record 9 of Set 7 | boyolangu
# Processing Record 10 of Set 7 | clyde river
# Processing Record 11 of Set 7 | biryusinsk
# Processing Record 12 of Set 7 | beidao
# Processing Record 13 of Set 7 | voyinka
# Processing Record 14 of Set 7 | muros
# Processing Record 15 of Set 7 | saint-philippe
# Processing Record 16 of Set 7 | touros
# Processing Record 17 of Set 7 | jojoima
# Processing Record 18 of Set 7 | amasya
# Processing Record 19 of Set 7 | severouralsk
# Processing Record 20 of Set 7 | sorland
# Processing Record 21 of Set 7 | krasnoborsk
# Processing Record 22 of Set 7 | eldama ravine
# Processing Record 23 of Set 7 | shenjiamen
# Processing Record 24 of Set 7 | victoria point
# Processing Record 25 of Set 7 | andros town
# Processing Record 26 of Set 7 | ondorhaan
# City not found. Skipping...
# Processing Record 27 of Set 7 | los llanos de aridane
# Processing Record 28 of Set 7 | nichinan
# Processing Record 29 of Set 7 | chiredzi
# Processing Record 30 of Set 7 | san-pedro
# Processing Record 31 of Set 7 | ust-uda
# Processing Record 32 of Set 7 | fallon
# Processing Record 33 of Set 7 | noumea
# Processing Record 34 of Set 7 | vostok
# Processing Record 35 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 36 of Set 7 | owase
# Processing Record 37 of Set 7 | nadym
# Processing Record 38 of Set 7 | carauari
# Processing Record 39 of Set 7 | padang
# Processing Record 40 of Set 7 | longyearbyen
# Processing Record 41 of Set 7 | uporovo
# Processing Record 42 of Set 7 | norman wells
# Processing Record 43 of Set 7 | betare oya
# Processing Record 44 of Set 7 | campana
# Processing Record 45 of Set 7 | yandoon
# City not found. Skipping...
# Processing Record 46 of Set 7 | portobelo
# Processing Record 47 of Set 7 | les cayes
# Processing Record 48 of Set 7 | havoysund
# Processing Record 49 of Set 7 | birin
# Processing Record 50 of Set 7 | kyzyl-suu
# Processing Record 1 of Set 8 | waingapu
# Processing Record 2 of Set 8 | suzhou
# Processing Record 3 of Set 8 | kuito
# Processing Record 4 of Set 8 | cuamba
# Processing Record 5 of Set 8 | nhulunbuy
# Processing Record 6 of Set 8 | karlstad
# Processing Record 7 of Set 8 | chekhov
# Processing Record 8 of Set 8 | avera
# Processing Record 9 of Set 8 | port pirie
# Processing Record 10 of Set 8 | kloulklubed
# Processing Record 11 of Set 8 | manica
# Processing Record 12 of Set 8 | soltau
# Processing Record 13 of Set 8 | eyl
# Processing Record 14 of Set 8 | jumla
# Processing Record 15 of Set 8 | ostrovnoy
# Processing Record 16 of Set 8 | aksarayskiy
# Processing Record 17 of Set 8 | abaetetuba
# Processing Record 18 of Set 8 | bathsheba
# Processing Record 19 of Set 8 | bumba
# Processing Record 20 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 21 of Set 8 | panama city
# Processing Record 22 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 23 of Set 8 | tambul
# City not found. Skipping...
# Processing Record 24 of Set 8 | katherine
# Processing Record 25 of Set 8 | kimbe
# Processing Record 26 of Set 8 | alyangula
# Processing Record 27 of Set 8 | maniitsoq
# Processing Record 28 of Set 8 | la macarena
# Processing Record 29 of Set 8 | casper
# Processing Record 30 of Set 8 | itarema
# Processing Record 31 of Set 8 | waipawa
# Processing Record 32 of Set 8 | stepnyak
# Processing Record 33 of Set 8 | pacific grove
# Processing Record 34 of Set 8 | megion
# Processing Record 35 of Set 8 | maracacume
# Processing Record 36 of Set 8 | mataram
# Processing Record 37 of Set 8 | miandrivazo
# Processing Record 38 of Set 8 | santa barbara
# Processing Record 39 of Set 8 | pangai
# Processing Record 40 of Set 8 | stony plain
# Processing Record 41 of Set 8 | bababe
# City not found. Skipping...
# Processing Record 42 of Set 8 | plettenberg bay
# Processing Record 43 of Set 8 | alice springs
# Processing Record 44 of Set 8 | arraial do cabo
# Processing Record 45 of Set 8 | jinchengjiang
# City not found. Skipping...
# Processing Record 46 of Set 8 | de aar
# Processing Record 47 of Set 8 | buala
# Processing Record 48 of Set 8 | bandarbeyla
# Processing Record 49 of Set 8 | panzhihua
# Processing Record 50 of Set 8 | japura
# Processing Record 1 of Set 9 | kailua
# Processing Record 2 of Set 9 | pringsewu
# Processing Record 3 of Set 9 | hofn
# Processing Record 4 of Set 9 | carnarvon
# Processing Record 5 of Set 9 | kaputa
# Processing Record 6 of Set 9 | gambela
# Processing Record 7 of Set 9 | chardara
# Processing Record 8 of Set 9 | ulladulla
# Processing Record 9 of Set 9 | rocha
# Processing Record 10 of Set 9 | whittlesea
# Processing Record 11 of Set 9 | nuuk
# Processing Record 12 of Set 9 | harwich
# Processing Record 13 of Set 9 | sinnamary
# Processing Record 14 of Set 9 | kattivakkam
# Processing Record 15 of Set 9 | biak
# Processing Record 16 of Set 9 | karpogory
# Processing Record 17 of Set 9 | winslow
# Processing Record 18 of Set 9 | sicuani
# Processing Record 19 of Set 9 | vestmannaeyjar
# Processing Record 20 of Set 9 | owerri
# Processing Record 21 of Set 9 | erenhot
# Processing Record 22 of Set 9 | sindand
# City not found. Skipping...
# Processing Record 23 of Set 9 | samarai
# Processing Record 24 of Set 9 | leningradskiy
# Processing Record 25 of Set 9 | paradwip
# City not found. Skipping...
# Processing Record 26 of Set 9 | elko
# Processing Record 27 of Set 9 | peterhead
# Processing Record 28 of Set 9 | ergani
# Processing Record 29 of Set 9 | bantry
# Processing Record 30 of Set 9 | dullewala
# Processing Record 31 of Set 9 | kresttsy
# Processing Record 32 of Set 9 | ormara
# Processing Record 33 of Set 9 | mutis
# Processing Record 34 of Set 9 | bolungarvik
# City not found. Skipping...
# Processing Record 35 of Set 9 | blythe
# Processing Record 36 of Set 9 | gorontalo
# Processing Record 37 of Set 9 | kyshtovka
# Processing Record 38 of Set 9 | satitoa
# City not found. Skipping...
# Processing Record 39 of Set 9 | el tocuyo
# Processing Record 40 of Set 9 | san jose
# Processing Record 41 of Set 9 | ganzhou
# Processing Record 42 of Set 9 | inderborskiy
# City not found. Skipping...
# Processing Record 43 of Set 9 | bundaberg
# Processing Record 44 of Set 9 | batagay-alyta
# Processing Record 45 of Set 9 | kruisfontein
# Processing Record 46 of Set 9 | sataua
# City not found. Skipping...
# Processing Record 47 of Set 9 | humaita
# Processing Record 48 of Set 9 | faya
# Processing Record 49 of Set 9 | north branch
# Processing Record 50 of Set 9 | rafaela
# Processing Record 1 of Set 10 | mayna
# Processing Record 2 of Set 10 | namibe
# Processing Record 3 of Set 10 | vao
# Processing Record 4 of Set 10 | ahipara
# Processing Record 5 of Set 10 | oksfjord
# Processing Record 6 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 7 of Set 10 | malmo
# Processing Record 8 of Set 10 | necochea
# Processing Record 9 of Set 10 | husavik
# Processing Record 10 of Set 10 | kurumkan
# Processing Record 11 of Set 10 | bogoslovka
# Processing Record 12 of Set 10 | komsomolskiy
# Processing Record 13 of Set 10 | aleksandrovsk-sakhalinskiy
# Processing Record 14 of Set 10 | lagoa
# Processing Record 15 of Set 10 | warqla
# City not found. Skipping...
# Processing Record 16 of Set 10 | asmar
# Processing Record 17 of Set 10 | nepa nagar
# Processing Record 18 of Set 10 | kahului
# Processing Record 19 of Set 10 | banda aceh
# Processing Record 20 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 21 of Set 10 | ouallam
# Processing Record 22 of Set 10 | jatai
# Processing Record 23 of Set 10 | saint-michel-des-saints
# Processing Record 24 of Set 10 | san cristobal
# Processing Record 25 of Set 10 | sao gabriel da cachoeira
# Processing Record 26 of Set 10 | makakilo city
# Processing Record 27 of Set 10 | vardo
# Processing Record 28 of Set 10 | ponta grossa
# Processing Record 29 of Set 10 | burnie
# Processing Record 30 of Set 10 | tucuman
# Processing Record 31 of Set 10 | ketchikan
# Processing Record 32 of Set 10 | savelugu
# Processing Record 33 of Set 10 | lengshuitan
# Processing Record 34 of Set 10 | kokopo
# Processing Record 35 of Set 10 | coahuayana
# Processing Record 36 of Set 10 | mimongo
# Processing Record 37 of Set 10 | tanabe
# Processing Record 38 of Set 10 | katsuura
# Processing Record 39 of Set 10 | atambua
# Processing Record 40 of Set 10 | manzhouli
# Processing Record 41 of Set 10 | arman
# Processing Record 42 of Set 10 | esperance
# Processing Record 43 of Set 10 | catalina
# Processing Record 44 of Set 10 | kichera
# Processing Record 45 of Set 10 | savannah bight
# Processing Record 46 of Set 10 | guanica
# Processing Record 47 of Set 10 | chunhuhub
# Processing Record 48 of Set 10 | magadan
# Processing Record 49 of Set 10 | bullhead city
# Processing Record 50 of Set 10 | jomalig
# City not found. Skipping...
# Processing Record 1 of Set 11 | barcelos
# Processing Record 2 of Set 11 | quatre cocos
# Processing Record 3 of Set 11 | nakamura
# Processing Record 4 of Set 11 | kholm
# Processing Record 5 of Set 11 | luau
# Processing Record 6 of Set 11 | cairns
# Processing Record 7 of Set 11 | gimli
# Processing Record 8 of Set 11 | trairi
# Processing Record 9 of Set 11 | kango
# Processing Record 10 of Set 11 | gazli
# Processing Record 11 of Set 11 | teya
# Processing Record 12 of Set 11 | reforma
# Processing Record 13 of Set 11 | road town
# Processing Record 14 of Set 11 | warri
# Processing Record 15 of Set 11 | kavaratti
# Processing Record 16 of Set 11 | kozluk
# Processing Record 17 of Set 11 | sangar
# Processing Record 18 of Set 11 | baykit
# Processing Record 19 of Set 11 | ilulissat
# Processing Record 20 of Set 11 | ninghai
# Processing Record 21 of Set 11 | malkangiri
# Processing Record 22 of Set 11 | olga
# Processing Record 23 of Set 11 | guarapari
# Processing Record 24 of Set 11 | fort nelson
# Processing Record 25 of Set 11 | aranos
# Processing Record 26 of Set 11 | aripuana
# Processing Record 27 of Set 11 | inirida
# Processing Record 28 of Set 11 | conchal
# Processing Record 29 of Set 11 | scottsburgh
# City not found. Skipping...
# Processing Record 30 of Set 11 | batavia
# Processing Record 31 of Set 11 | great falls
# Processing Record 32 of Set 11 | marawi
# Processing Record 33 of Set 11 | itaituba
# Processing Record 34 of Set 11 | khani
# Processing Record 35 of Set 11 | ballina
# Processing Record 36 of Set 11 | srednekolymsk
# Processing Record 37 of Set 11 | svetlaya
# Processing Record 38 of Set 11 | alta floresta
# Processing Record 39 of Set 11 | tura
# Processing Record 40 of Set 11 | atar
# Processing Record 41 of Set 11 | tyrma
# Processing Record 42 of Set 11 | boshnyakovo
# Processing Record 43 of Set 11 | saint pete beach
# Processing Record 44 of Set 11 | lephepe
# City not found. Skipping...
# Processing Record 45 of Set 11 | am timan
# Processing Record 46 of Set 11 | mapiri
# Processing Record 47 of Set 11 | gazni
# City not found. Skipping...
# Processing Record 48 of Set 11 | tilichiki
# Processing Record 49 of Set 11 | aykhal
# Processing Record 50 of Set 11 | eureka
# Processing Record 1 of Set 12 | palic
# Processing Record 2 of Set 12 | paita
# Processing Record 3 of Set 12 | roros
# Processing Record 4 of Set 12 | port macquarie
# Processing Record 5 of Set 12 | deputatskiy
# Processing Record 6 of Set 12 | carmarthen
# Processing Record 7 of Set 12 | urumqi
# Processing Record 8 of Set 12 | mandalgovi
# Processing Record 9 of Set 12 | xacmaz
# Processing Record 10 of Set 12 | hobyo
# Processing Record 11 of Set 12 | tazovskiy
# Processing Record 12 of Set 12 | carballo
# Processing Record 13 of Set 12 | hanzhong
# Processing Record 14 of Set 12 | nabul
# City not found. Skipping...
# Processing Record 15 of Set 12 | warrenton
# Processing Record 16 of Set 12 | oussouye
# Processing Record 17 of Set 12 | kapuskasing
# Processing Record 18 of Set 12 | margate
# Processing Record 19 of Set 12 | cockburn town
# Processing Record 20 of Set 12 | grand centre
# City not found. Skipping...
# Processing Record 21 of Set 12 | aksay
# Processing Record 22 of Set 12 | hay river
# Processing Record 23 of Set 12 | irbeyskoye
# Processing Record 24 of Set 12 | codrington
# Processing Record 25 of Set 12 | okhotsk
# Processing Record 26 of Set 12 | barranca
# Processing Record 27 of Set 12 | tyldesley
# Processing Record 28 of Set 12 | maningrida
# Processing Record 29 of Set 12 | hlotse
# Processing Record 30 of Set 12 | vila do maio
# Processing Record 31 of Set 12 | casas grandes
# Processing Record 32 of Set 12 | kirksville
# Processing Record 33 of Set 12 | geilo
# Processing Record 34 of Set 12 | santa lucia
# Processing Record 35 of Set 12 | vendas novas
# Processing Record 36 of Set 12 | russell
# Processing Record 37 of Set 12 | shirokiy
# Processing Record 38 of Set 12 | sao jose da coroa grande
# Processing Record 39 of Set 12 | hami
# Processing Record 40 of Set 12 | turukhansk
# Processing Record 41 of Set 12 | yanan
# City not found. Skipping...
# Processing Record 42 of Set 12 | iracoubo
# Processing Record 43 of Set 12 | tubruq
# City not found. Skipping...
# Processing Record 44 of Set 12 | joensuu
# Processing Record 45 of Set 12 | odweyne
# Processing Record 46 of Set 12 | myitkyina
# Processing Record 47 of Set 12 | samalaeulu
# City not found. Skipping...
# Processing Record 48 of Set 12 | columbus
# Processing Record 49 of Set 12 | northam
# Processing Record 50 of Set 12 | yenagoa
# Processing Record 1 of Set 13 | ligaya
# Processing Record 2 of Set 13 | shingu
# Processing Record 3 of Set 13 | flinders
# Processing Record 4 of Set 13 | corrente
# Processing Record 5 of Set 13 | borba
# Processing Record 6 of Set 13 | san juan de la maguana
# Processing Record 7 of Set 13 | solnechnyy
# Processing Record 8 of Set 13 | blagoyevo
# Processing Record 9 of Set 13 | antalaha
# Processing Record 10 of Set 13 | ullapool
# Processing Record 11 of Set 13 | realeza
# Processing Record 12 of Set 13 | oranjemund
# Processing Record 13 of Set 13 | walvis bay
# Processing Record 14 of Set 13 | awbari
# Processing Record 15 of Set 13 | talnakh
# Processing Record 16 of Set 13 | pisco
# Processing Record 17 of Set 13 | port hawkesbury
# Processing Record 18 of Set 13 | san andres
# Processing Record 19 of Set 13 | karpathos
# Processing Record 20 of Set 13 | abnub
# Processing Record 21 of Set 13 | praia
# Processing Record 22 of Set 13 | shchigry
# Processing Record 23 of Set 13 | byron bay
# Processing Record 24 of Set 13 | vossevangen
# Processing Record 25 of Set 13 | bratsk
# Processing Record 26 of Set 13 | vryheid
# Processing Record 27 of Set 13 | atasu
# Processing Record 28 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 29 of Set 13 | zhanatas
# City not found. Skipping...
# Processing Record 30 of Set 13 | lasa
# Processing Record 31 of Set 13 | peleduy
# Processing Record 32 of Set 13 | bahia honda
# Processing Record 33 of Set 13 | george
# Processing Record 34 of Set 13 | greencastle
# Processing Record 35 of Set 13 | humberto de campos
# Processing Record 36 of Set 13 | bekhtery
# Processing Record 37 of Set 13 | tecoanapa
# Processing Record 38 of Set 13 | oppdal
# Processing Record 39 of Set 13 | hualmay
# Processing Record 40 of Set 13 | shchuchye
# City not found. Skipping...
# Processing Record 41 of Set 13 | suksun
# Processing Record 42 of Set 13 | hudiksvall
# Processing Record 43 of Set 13 | kautokeino
# Processing Record 44 of Set 13 | chaparral
# Processing Record 45 of Set 13 | tonantins
# Processing Record 46 of Set 13 | solovetskiy
# City not found. Skipping...
# Processing Record 47 of Set 13 | beloha
# Processing Record 48 of Set 13 | leonidovo
# Processing Record 49 of Set 13 | bay roberts
# Processing Record 50 of Set 13 | calbuco
# Processing Record 1 of Set 14 | tatawin
# Processing Record 2 of Set 14 | zolotinka
# City not found. Skipping...
# Processing Record 3 of Set 14 | shirvan
# Processing Record 4 of Set 14 | bairiki
# Processing Record 5 of Set 14 | kibaya
# Processing Record 6 of Set 14 | marcona
# City not found. Skipping...
# Processing Record 7 of Set 14 | tessalit
# Processing Record 8 of Set 14 | hoopstad
# Processing Record 9 of Set 14 | namatanai
# Processing Record 10 of Set 14 | el faiyum
# City not found. Skipping...
# Processing Record 11 of Set 14 | tsaotun
# City not found. Skipping...
# Processing Record 12 of Set 14 | kushima
# Processing Record 13 of Set 14 | fairbanks
# Processing Record 14 of Set 14 | nizhnevartovsk
# Processing Record 15 of Set 14 | saint-augustin
# Processing Record 16 of Set 14 | muscat
# Processing Record 17 of Set 14 | najran
# Processing Record 18 of Set 14 | santiago
# Processing Record 19 of Set 14 | marquette
# Processing Record 20 of Set 14 | celestun
# Processing Record 21 of Set 14 | new kensington
# Processing Record 22 of Set 14 | poum
# Processing Record 23 of Set 14 | tuatapere
# Processing Record 24 of Set 14 | port hedland
# Processing Record 25 of Set 14 | rapid city
# Processing Record 26 of Set 14 | ghanzi
# Processing Record 27 of Set 14 | la joya
# Processing Record 28 of Set 14 | ukiah
# Processing Record 29 of Set 14 | naze
# Processing Record 30 of Set 14 | haines junction
# Processing Record 31 of Set 14 | ha tinh
# Processing Record 32 of Set 14 | deyang
# Processing Record 33 of Set 14 | ksenyevka
# City not found. Skipping...
# Processing Record 34 of Set 14 | vanimo
# Processing Record 35 of Set 14 | abbeville
# Processing Record 36 of Set 14 | vestmanna
# Processing Record 37 of Set 14 | san isidro
# Processing Record 38 of Set 14 | wenling
# Processing Record 39 of Set 14 | mehriz
# Processing Record 40 of Set 14 | kerman
# Processing Record 41 of Set 14 | ulaanbaatar
# Processing Record 42 of Set 14 | udachnyy
# Processing Record 43 of Set 14 | naples
# Processing Record 44 of Set 14 | beyneu
# Processing Record 45 of Set 14 | tongliao
# Processing Record 46 of Set 14 | wewak
# Processing Record 47 of Set 14 | kudahuvadhoo
# Processing Record 48 of Set 14 | tahta
# Processing Record 49 of Set 14 | bonavista
# Processing Record 50 of Set 14 | labuhan
# Processing Record 1 of Set 15 | lagoa vermelha
# Processing Record 2 of Set 15 | manggar
# Processing Record 3 of Set 15 | darnah
# Processing Record 4 of Set 15 | bubaque
# Processing Record 5 of Set 15 | barawe
# City not found. Skipping...
# Processing Record 6 of Set 15 | kirakira
# Processing Record 7 of Set 15 | roebourne
# Processing Record 8 of Set 15 | shimoda
# Processing Record 9 of Set 15 | lipari
# Processing Record 10 of Set 15 | medea
# Processing Record 11 of Set 15 | shellbrook
# Processing Record 12 of Set 15 | dudinka
# Processing Record 13 of Set 15 | plaisance-du-touch
# Processing Record 14 of Set 15 | skagastrond
# City not found. Skipping...
# Processing Record 15 of Set 15 | kazalinsk
# City not found. Skipping...
# Processing Record 16 of Set 15 | yukamenskoye
# Processing Record 17 of Set 15 | huimanguillo
# Processing Record 18 of Set 15 | buqayq
# City not found. Skipping...
# Processing Record 19 of Set 15 | dhanwar
# Processing Record 20 of Set 15 | teplyk
# Processing Record 21 of Set 15 | omboue
# Processing Record 22 of Set 15 | gela
# Processing Record 23 of Set 15 | taoudenni
# Processing Record 24 of Set 15 | pathein
# Processing Record 25 of Set 15 | mercedes
# Processing Record 26 of Set 15 | pokosnoye
# Processing Record 27 of Set 15 | la rioja
# Processing Record 28 of Set 15 | tucupita
# Processing Record 29 of Set 15 | dukat
# Processing Record 30 of Set 15 | saint john
# Processing Record 31 of Set 15 | banjar
# Processing Record 32 of Set 15 | high level
# Processing Record 33 of Set 15 | chengzihe
# Processing Record 34 of Set 15 | lensk
# Processing Record 35 of Set 15 | kamienna gora
# Processing Record 36 of Set 15 | bourail
# Processing Record 37 of Set 15 | chicama
# Processing Record 38 of Set 15 | conde
# Processing Record 39 of Set 15 | manado
# Processing Record 40 of Set 15 | sergiyev posad
# Processing Record 41 of Set 15 | abu zabad
# Processing Record 42 of Set 15 | mikhaylovka
# Processing Record 43 of Set 15 | amparafaravola
# Processing Record 44 of Set 15 | khorixas
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 673

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Yellowknife      CA  62.4560 -114.3525     18.12        86         100
# 1       Hobart      AU -42.8794  147.3294     59.25        71          75
# 2      Mataura      NZ -46.1927  168.8643     49.75        61          68
# 3  Port Alfred      ZA -33.5906   26.8910     62.19        90          61
# 4     Hermanus      ZA -34.4187   19.2345     56.80        70           7
# 5       Castro      BR -24.7911  -50.0119     61.52        94         100
# 6       Hasaki      JP  35.7333  140.8333     51.22        68           0
# 7   Vila Velha      BR -20.3297  -40.2925     76.95        84          75
# 8    Grindavik      IS  63.8424  -22.4338     37.87        93           0
# 9    Zhigalovo      RU  54.8097  105.1578     -2.09        86         100
#
#    Wind Speed Weather Description
# 0        3.44          light snow
# 1        5.75       broken clouds
# 2        1.97       broken clouds
# 3        3.60       broken clouds
# 4       12.44           clear sky
# 5        6.80     overcast clouds
# 6       19.22           clear sky
# 7       12.66       broken clouds
# 8       17.27           clear sky
# 9        9.66     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
#city_data_df.columns
city_data_df = city_data_df.rename(columns={'Weather Description':'Current Description'})
city_data_df.columns
#city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"

new_column_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity','Cloudiness', 'Wind Speed', 'Current Description']



# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head()
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Yellowknife      CA  62.4560 -114.3525     18.12        86         100
# 1       Hobart      AU -42.8794  147.3294     59.25        71          75
# 2      Mataura      NZ -46.1927  168.8643     49.75        61          68
# 3  Port Alfred      ZA -33.5906   26.8910     62.19        90          61
# 4     Hermanus      ZA -34.4187   19.2345     56.80        70           7
#
#    Wind Speed Current Description
# 0        3.44          light snow
# 1        5.75       broken clouds
# 2        1.97       broken clouds
# 3        3.60       broken clouds
# 4       12.44           clear sky

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
outputfile = 'WeatherPy_Database.csv'

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(outputfile, index_label="City_ID")
